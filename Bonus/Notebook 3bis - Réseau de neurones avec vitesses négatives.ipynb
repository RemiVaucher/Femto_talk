# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Les seules différences avec le Notebook 3 sont:
#
# - La fonction compute_exact_mass doit prendre en compte des vitesses négatives.
# - Les données d'entrainement doivent avoir des betas négatifs
#
# Le reste est similaire au modele 2

# %%
# A compiler

def compute_volfrac(X,g,side):
    if side<0:
        if g<np.min(X):
            v_f=0
        elif g>np.max(X):
            v_f=1
        else:
            v_f=g-np.min(X)
    else:
        if g<np.min(X):
            v_f=1
        elif g>np.max(X):
            v_f=0
        else:
            v_f=np.max(X)-g
    return v_f
                
        
    
X=np.array([-0.5,0.5])
g=0.4
f_v=compute_volfrac(X,g,-1)
print(f_v)
# Out:
# 0.9

# %%
# A compiler

def compute_exact_mass(X,g,side,b):
    Q_m=0
    if b>0:
        if side<0:
            if g+b<=X[1]:
                return(Q_m)
            elif (g+b>X[1])&(g<X[1]):
                Q_m=g+b-X[1]
                return(Q_m)
            else:
                Q_m=b
                return(Q_m)
        else:
            if g+b<=X[1]:
                Q_m=b
                return(Q_m)
            elif (g+b>X[1])&(g<X[1]):
                Q_m=X[1]-g
                return(Q_m)
            else:
                return(Q_m) 
    else:
        if side<0:
            if g<=X[1]:
                Q_m=0
                return(Q_m)
            elif (g+b<X[1])&(g>X[1]):
                Q_m=g-X[1]
                return(Q_m)
            else:
                Q_m=-b
                return(Q_m)
        else:
            if g+b>=X[1]:
                Q_m=0
                return(Q_m)
            elif (g+b<X[1])&(g>X[1]):
                Q_m=X[1]-g-b
                return(Q_m)
            else:
                Q_m=-b
                return(Q_m)
        
        
g=2.21
b=-0.99       
side=1
X=np.linspace(-0.5,1.5,3)
X_frac=np.linspace(-1.5,0.5,3)
E_m=np.array([])
for i in X_frac:
    Xtemp=np.array([i,i+1])
    E_m=np.append(E_m,compute_exact_mass(Xtemp,g,side,b))
print(E_m)
plt.plot(X,E_m)
# Out:
# [0.   0.   0.28]

# %%
# A compiler

def generate_training_data(ngammas,nbetas):
    entree_train = np.zeros((ngammas*nbetas*2,4))
    # J'initialise mes entrées: mes entrées sont les fractions volumiques
    # calculées pour chaque betas, chaques gammas et chaque side
    # il y aura donc ngammas*nbeta*2 vecteurs de tailles 3+1 (on stocke beta aussi)
    label_train = np.zeros((ngammas*nbetas*2,3))
    # J'initialise mes label: mes labels sont les quantités de matières
    # exactes passant par chaque bord de maille: ngammas*nbetas*2 vecteurs 
    # de taille 3
    G = np.random.uniform(-2,2,ngammas)
    # je génère ngammas valeurs de gammas sorties sous la loi unif
    B = np.random.uniform(-1,1,nbetas)
    # pareil pour beta
    S=np.array([-1,1])
    # Ca c'est mes sides (-1 ou 1)
    X=np.array([[-1.5,-0.5],[-0.5,0.5],[0.5,1.5]])
    # Ca c'est mes mailles
    i=0
    for g in G:
        j=0
        for b in B:
            k=0
            for s in S:
                Vol=np.array([compute_volfrac(np.array([-1.5,-0.5]),g,s),
                              compute_volfrac(np.array([-0.5,0.5]),g,s),
                              compute_volfrac(np.array([0.5,1.5]),g,s)])
                entree_train[i+j+k,:]=np.append(Vol,b)
                #Je crée une matrice contenant mes sorties
                Mass=np.array([compute_exact_mass(np.array([-1.5,-0.5]),g,s,b),
                               compute_exact_mass(np.array([-0.5,0.5]),g,s,b),
                               compute_exact_mass(np.array([0.5,1.5]),g,s,b)])
                label_train[i+j+k,:]=Mass
                #pareil pour mes labels
                k=k+1
            j=j+k
        i=i+j
    entree_tens = tf.constant(entree_train)
    label_tens = tf.constant(label_train)
    dataset=tf.data.Dataset.from_tensor_slices((entree_tens,label_tens))
    # dataset=tf.data.Dataset.from_tensor_slices((entree_train,label_train))
    # J'en fait direct un tenseur de tensorflow: j'ai galéré un peu à produire
    # un tenseur qui passait dans les entrée du NN, mais maintenant ca colle!
    return(dataset)

# %%
#Ne pas compiler

batchsize = 100 #Je les regroupe par paquet de 5à, parce que si on veux
#Un nombre de gammas/betas suffisant, les dim explose.
ngammas = 300
nbetas = 200
data_set = generate_training_data(ngammas,nbetas)
data_set = data_set.cache()
data_set = data_set.shuffle(ngammas*nbetas*2)
# Je mélange
data_set = data_set.batch(batchsize).prefetch(tf.data.AUTOTUNE)
# Je batch et prefetch (pour les fans de la cité de la peur:
# "Alors que revoilaaaa la sous prefeeeeetch")
data_set
# Out:
# <PrefetchDataset shapes: ((None, 4), (None, 3)), types: (tf.float64, tf.float64)>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow import keras

# %%
# Ne pas compiler

n=4
m=20
model = Sequential()
model.add(Dense(units=2*n,input_dim=4,activation='relu'))
# Première couche: entrée 4 (3FracVol+1Vit)
model.add(Dense(units=4*n,activation='relu'))
model.add(Dense(units=2*n,activation='relu'))

model.add(Dense(units=3,activation='relu'))
#Troisième couche: sortie 3 (3 masse exacte)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 8)                 40
#
#  dense_9 (Dense)             (None, 16)                144
#
#  dense_10 (Dense)            (None, 8)                 136
#
#  dense_11 (Dense)            (None, 3)                 27
#
# =================================================================
# Total params: 347
# Trainable params: 347
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Ne pas compiler

model.compile(optimizer = Adam(learning_rate=1e-3),
             loss = keras.losses.mean_squared_error,
             metrics=[keras.metrics.mean_squared_error])
# Dans le papier qui établi la méthode, ils optimisent avec
# une descente de gradient stochastique, et la fonction loss
# c'est MSE. Donc j'ai fait pareil

# %%
# Ne pas compiler

epoch = 200
model.fit(data_set, epochs = epoch, verbose=1)
# Out:
# Epoch 1/200
# 1200/1200 [==============================] - 1s 618us/step - loss: 0.0205 - mean_squared_error: 0.0205
# Epoch 2/200
# 1200/1200 [==============================] - 1s 738us/step - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 3/200
# 1200/1200 [==============================] - 1s 663us/step - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 4/200
# 1200/1200 [==============================] - 1s 644us/step - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 5/200
# 1200/1200 [==============================] - 1s 695us/step - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 6/200
# 1200/1200 [==============================] - 1s 711us/step - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 7/200
# 1200/1200 [==============================] - 1s 682us/step - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 8/200
# 1200/1200 [==============================] - 1s 679us/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 9/200
# 1200/1200 [==============================] - 1s 642us/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch
/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 180/200
# 1200/1200 [==============================] - 1s 571us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 181/200
# 1200/1200 [==============================] - 1s 582us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 182/200
# 1200/1200 [==============================] - 1s 579us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 183/200
# 1200/1200 [==============================] - 1s 585us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 184/200
# 1200/1200 [==============================] - 1s 586us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 185/200
# 1200/1200 [==============================] - 1s 584us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 186/200
# 1200/1200 [==============================] - 1s 586us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 187/200
# 1200/1200 [==============================] - 1s 597us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 188/200
# 1200/1200 [==============================] - 1s 591us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 189/200
# 1200/1200 [==============================] - 1s 600us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 190/200
# 1200/1200 [==============================] - 1s 616us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 191/200
# 1200/1200 [==============================] - 1s 584us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 192/200
# 1200/1200 [==============================] - 1s 584us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 193/200
# 1200/1200 [==============================] - 1s 584us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 194/200
# 1200/1200 [==============================] - 1s 588us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 195/200
# 1200/1200 [==============================] - 1s 583us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 196/200
# 1200/1200 [==============================] - 1s 596us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 197/200
# 1200/1200 [==============================] - 1s 584us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 198/200
# 1200/1200 [==============================] - 1s 591us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 199/200
# 1200/1200 [==============================] - 1s 624us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 200/200
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0023 - mean_squared_error: 0.00 - 1s 755us/step - loss: 0.0023 - mean_squared_error: 0.0023

# %%
#A compiler

model=keras.models.load_model('model3')

# %%
# A compiler (plusieurs fois pour voir différentes trajectoires)

X = np.array([[-1.5,-0.5],[-0.5,0.5],[0.5,1.5]])
g = np.random.uniform(low=-1.5,high=1.5,size=1)[0]
B = np.linspace(-1,1,21)
print(g)
side = (-1)**(np.random.randint(0,2))
print(side)
m_d_tot=np.array([])
mass_pred_tot=np.array([[]])
for b in B:
    f_v=np.array([])
    m_d=np.array([])
    mass_pred=np.array([])
    for x in X:
        f_v_temp = compute_volfrac(x,g,side)
        #mass_pred = np.append(mass_pred,model.predict(f_v_temp1.reshape(1,2)))
        f_v = np.append(f_v,f_v_temp)
        m_d = np.append(m_d,compute_exact_mass(x,g,side,b))
    mass_pred=model.predict(np.append(f_v,b).reshape(1,4))
    
    m_d_tot = np.append(m_d_tot,m_d)
    mass_pred_tot = np.append(mass_pred_tot,[[mass_pred]])

#print(mass_pred_tot)  
#print(len(mass_pred_tot))
#print(m_d_tot)
# Je créé ma sortie exacte
#fig=plt.figure(figsize=(5,5))
#ax=fig.add_subplot(111)
#ax.scatter(Xplot,m_d,c='b',marker="o")
#ax.scatter(Xplot,mass_pred,c='r',marker="+")
fig = plt.figure()
fig.set_facecolor('white')
plt.plot(B, mass_pred_tot[1::3], color='blue', label='Prédiction')
plt.plot(B,m_d_tot[1::3] , color='red', label='Théorique')
plt.legend()
plt.show()
# Out:
# -0.9986502881796144
# -1

# %%
A=np.array([1,1,0.5,0.8]).T
print(A.reshape(1,4))
model.predict(A.reshape(1,4)).reshape(3,1)[0][0]
# Out:
# [[1.  1.  0.5 0.8]]
# 0.8020619

# %%
model.save('model4')
# Out:
# INFO:tensorflow:Assets written to: model4\assets
